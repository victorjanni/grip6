# %% [markdown]
# ### Author: janni victor prasad
# ### Profile: Data Science and Business Analytics
# ### From:  The Sparks Foundation  #GRIPFeb2022
# ### Email:victorcoc123vr@gmail.com
# ### Cell:8555056943

# %% [markdown]
# ### TASK 6: Implementing a Decision Tree Classifier and Visualizing it graphically
#
# #### Objective:
# For the given ‘Iris’ dataset, building a decision tree classifier to predict the new data to the right class.

# %% [markdown]
# ### Importing all the essential libraries

# %%
# Importing all essential libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing the dataset

# %%
# Importing the dataset
# Load the iris dataset
from sklearn import datasets
iris = datasets.load_iris()
data = pd.DataFrame(iris.data, columns = iris.feature_names)
y=iris.target
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### Fitting the data to Decision Tree Classifier

# %%
# fitting the decision tress classifier to data
from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier(criterion="entropy",random_state=0)  # by default criterion is "gini"
dtree.fit(data,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ### Visualizing the Decision Tree Algorithm to understand it better

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(18,10))
plot_tree(dtree,feature_names=iris.feature_names,filled="True")
# Out:
# [Text(502.20000000000005, 498.3, 'petal width (cm) <= 0.8\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(424.9384615384615, 407.70000000000005, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(579.4615384615385, 407.70000000000005, 'petal width (cm) <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(309.04615384615386, 317.1, 'petal length (cm) <= 4.95\nentropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(154.52307692307693, 226.5, 'petal width (cm) <= 1.65\nentropy = 0.146\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(77.26153846153846, 135.89999999999998, 'entropy = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(231.7846153846154, 135.89999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(463.5692307692308, 226.5, 'petal width (cm) <= 1.55\nentropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(386.3076923076923, 135.89999999999998, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...
